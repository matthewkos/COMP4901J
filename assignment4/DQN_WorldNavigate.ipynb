# %% [markdown]
# # World Navigation with DQN
#
# In this exercise you will play a world navigation game with Deep Q-Networks. The agent learn to solve a navigation task in a basic grid world. It will be built upon the simple one layer Q-network you created in Exercise 1.

# %% [markdown]
# In order to transform an ordinary Q-Network into a DQN you will be making the following improvements:
# 1. Going from a single-layer network to a multi-layer convolutional network.
# 2. Implementing Experience Replay, which will allow our network to train itself using stored memories from it's experience.
# 3. Utilizing a second "target" network, which we will use to compute target Q-values during our updates.

# %% [markdown]
# You will also implement two simple additional improvements to the DQN architecture, Double DQN and Dueling DQN, that allow for improved performance, stability, and faster training time. In the end you will have a network that can tackle a number of challenging Atari games, and we will demonstrate how to train the DQN to learn a basic navigation task.

# %%
from __future__ import division

import gym
import numpy as np
import random
import tensorflow as tf
import tensorflow.contrib.slim as slim
import matplotlib.pyplot as plt
import scipy.misc
import os
# %matplotlib inline

# %% [markdown]
# ### Load the game environment

# %%
from gridworld import gameEnv

env = gameEnv(partial=False,size=5)

# %% [markdown]
# Above is an example of a starting environment in our simple game. The game environment outputs 84x84x3 color images, and uses function calls as similar to the OpenAI gym as possible. The agent controls the blue square, and can move up, down, left, or right. The goal is to move to the green square (for +1 reward) and avoid the red square (for -1 reward).
#
# At the start of each episode all squares are randomly placed within a 5x5 grid-world. The agent has 50 steps to achieve as large a reward as possible. Because they are randomly positioned, the agent needs to do more than simply learn a fixed path, as was the case in the FrozenLake environment from Exercise 1. Instead the agent must learn a notion of spatial relationships between the blocks.
#
# *Feel free to adjust the size of the gridworld (default 5). Making it smaller provides an easier task for our DQN agent, while making the world larger increases the challenge.*

# %% [markdown]
# ### Addition 1: Convolutional Layers

# %% [markdown]
# The first major addition to make DQNs work is to use convolutional layers to set up the networks. We are now familiar with convolutional layers after assignment `1-3`. For more information, see the [Tensorflow documentation](https://www.tensorflow.org/api_docs/).

# %% [markdown]
# ### Addition 2: Experience Replay

# %% [markdown]
# The second major addition to make DQNs work is Experience Replay. The basic idea is that by storing an agent’s experiences, and then randomly drawing batches of them to train the network, we can more robustly learn to perform well in the task. By keeping the experiences we draw random, we prevent the network from only learning about what it is immediately doing in the environment, and allow it to learn from a more varied array of past experiences.
#
# Each of these experiences are stored as a tuple of *(state,action,reward,next state)*. The Experience Replay buffer stores a fixed number of recent memories, and as new ones come in, old ones are removed. When the time comes to train, we simply draw a uniform batch of random memories from the buffer, and train our network with them.
#
# For our DQN, we build a simple class that allows us to store experies and sample them randomly to train the network:

# %%
class experience_buffer():
    def __init__(self, buffer_size = 50000):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self,experience):
        if len(self.buffer) + len(experience) >= self.buffer_size:
            self.buffer[0:(len(experience)+len(self.buffer))-self.buffer_size] = []
        self.buffer.extend(experience)
            
    def sample(self,size):
        return np.reshape(np.array(random.sample(self.buffer,size)),[size,5])

# %% [markdown]
# This is a simple function to resize our game frames:

# %%
def processState(states):
    return np.reshape(states,[21168]) # 84 x 84 x 3

# %% [markdown]
# ### Addition 3: Separate Target Network

# %% [markdown]
# The third major addition to the DQN that makes it unique is the utilization of a second network during the training procedure. This second network is used to generate the target-Q values that will be used to compute the loss for every action during training. Why not use just use one network for both estimations? The issue is that at every step of training, the Q-network’s values shift, and if we are using a constantly shifting set of values to adjust our network values, then the value estimations can easily spiral out of control. The network can become destabilized by falling into feedback loops between the target and estimated Q-values. In order to mitigate that risk, the target network’s weights are fixed, and only periodically or slowly updated to the primary Q-networks values. In this way training can proceed in a more stable manner.

# %% [markdown]
# These functions allow us to update the parameters of our target network with those of the primary network.

# %%
def updateTargetGraph(tfVars,tau):
    total_vars = len(tfVars)
    op_holder = []
    for idx,var in enumerate(tfVars[0:total_vars//2]):
        op_holder.append(tfVars[idx+total_vars//2].assign((var.value()*tau) + ((1-tau)*tfVars[idx+total_vars//2].value())))
    return op_holder

def updateTarget(op_holder,sess):
    for op in op_holder:
        sess.run(op)

# %% [markdown]
# With the additions above, we have everything we need to replicate the DQN.

# %% [markdown]
# ### Dueling DQN

# %% [markdown]
# In order to explain the reasoning behind the architecture changes that Dueling DQN makes, we need to first explain some a few additional reinforcement learning terms. The Q-values that we have been discussing so far correspond to how good it is to take a certain action given a certain state. This can be written as `Q(s,a)`. This action given state can actually be decomposed into two more fundamental notions of value. The first is the value function `V(s)`, which says simple how good it is to be in any given state. The second is the advantage function `A(a)`, which tells how much better taking a certain action would be compared to the others. We can then think of `Q` as being the combination of `V` and `A`. More formally:

# %% [markdown]
# $$ Q(s,a) =V(s) + A(a) $$

# %% [markdown]
# The goal of Dueling DQN is to have a network that separately computes the advantage and value functions, and combines them back into a single Q-function only at the final layer. It may seem somewhat pointless to do this at first glance. Why decompose a function that we will just put back together? The key to realizing the benefit is to appreciate that our reinforcement learning agent may not need to care about both value and advantage at any given time. We can achieve more robust estimates of state value by decoupling it from the necessity of being attached to specific actions.

# %% [markdown]
# ### Implementing the network itself

# %%
class Qnetwork():
    def __init__(self,h_size):
        #The network recieves a frame from the game, flattened into an array.
        #It then resizes it and processes it through four convolutional layers.
        #We use slim.conv2d to set up our network 
        self.scalarInput =  tf.placeholder(shape=[None,21168],dtype=tf.float32)
        self.imageIn = tf.reshape(self.scalarInput,shape=[-1,84,84,3])
        self.conv1 = slim.conv2d( \
            inputs=self.imageIn,num_outputs=32,kernel_size=[8,8],stride=[4,4],padding='VALID', biases_initializer=None)
        self.conv2 = slim.conv2d( \
            inputs=self.conv1,num_outputs=64,kernel_size=[4,4],stride=[2,2],padding='VALID', biases_initializer=None)
        self.conv3 = slim.conv2d( \
            inputs=self.conv2,num_outputs=64,kernel_size=[3,3],stride=[1,1],padding='VALID', biases_initializer=None)
        self.conv4 = slim.conv2d( \
            inputs=self.conv3,num_outputs=h_size,kernel_size=[7,7],stride=[1,1],padding='VALID', biases_initializer=None)
        
        ################################################################################
        # TODO: Implement Dueling DQN                                                  #
        # We take the output from the final convolutional layer i.e. self.conv4 and    #
        # split it into separate advantage and value streams.                          #
        # Outout: self.Advantage, self.Value                                           #
        # Hint: Refer to Fig.1 in [Dueling DQN](https://arxiv.org/pdf/1511.06581.pdf)  #
        #       In implementation, use tf.split to split into two branches. You may    #
        #       use xavier_initializer for initializing the two additional linear      #
        #       layers.                                                                # 
        ################################################################################
        self.flatten = tf.layers.flatten(self.conv4)
        # shape = (-1,512)
        self.Advantage_stream, self.Value_stream = tf.split(self.flatten,2,-1)
#         self.Advantage = slim.fully_connected(self.Advantage_stream, 1)
#         self.Value = slim.fully_connected(self.Value_stream, env.actions)
        self.Advantage = tf.layers.dense(self.Advantage_stream, 1)
        self.Value = tf.layers.dense(self.Value_stream, env.actions)
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        #Then combine them together to get our final Q-values. 
        #Please refer to Equation (9) in [Dueling DQN](https://arxiv.org/pdf/1511.06581.pdf)
        self.Qout = self.Value + tf.subtract(self.Advantage,tf.reduce_mean(self.Advantage,axis=1,keep_dims=True))
        self.predict = tf.argmax(self.Qout,1)
        
        #Below we obtain the loss by taking the sum of squares difference between the target and prediction Q values.
        self.targetQ = tf.placeholder(shape=[None],dtype=tf.float32)
        self.actions = tf.placeholder(shape=[None],dtype=tf.int32)
        self.actions_onehot = tf.one_hot(self.actions,env.actions,dtype=tf.float32)
        ################################################################################
        # TODO:                                                                        #
        # Obtain the loss (self.loss) by taking the sum of squares difference          #
        # between the target and prediction Q values.                                  #
        ################################################################################
        Q_s_a = tf.reduce_sum(tf.multiply(self.Qout, self.actions_onehot), axis=1)
        self.loss = tf.reduce_sum(tf.square(tf.subtract(Q_s_a, self.targetQ)))
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        
        self.trainer = tf.train.AdamOptimizer(learning_rate=0.0001)
        self.updateModel = self.trainer.minimize(self.loss)

# %% [markdown]
# ### Training the network

# %% [markdown]
# Setting all the training parameters

# %%
batch_size = 32 #How many experiences to use for each training step.
update_freq = 4 #How often to perform a training step.
y = .99 #Discount factor on the target Q-values
startE = 1 #Starting chance of random action
endE = 0.1 #Final chance of random action
annealing_steps = 10000. #How many steps of training to reduce startE to endE.
num_episodes = 5000 #How many episodes of game environment to train network with.
pre_train_steps = 10000 #How many steps of random actions before training begins.
max_epLength = 50 #The max allowed length of our episode.
load_model = False #Whether to load a saved model.
path = "./dqn" #The path to save our model to.
h_size = 512 #The size of the final convolutional layer before splitting it into Advantage and Value streams.
tau = 0.001 #Rate to update target network toward primary network

# %% [markdown]
# ### Double DQN

# %% [markdown]
# The main intuition behind Double DQN is that the regular DQN often overestimates the Q-values of the potential actions to take in a given state. While this would be fine if all actions were always overestimates equally, there was reason to believe this wasn’t the case. You can easily imagine that if certain suboptimal actions regularly were given higher Q-values than optimal actions, the agent would have a hard time ever learning the ideal policy. In order to correct for this, the authors of DDQN paper propose a simple trick: instead of taking the max over Q-values when computing the target-Q value for our training step, we use our primary network to chose an action, and our target network to generate the target Q-value for that action. By decoupling the action choice from the target Q-value generation, we are able to substantially reduce the overestimation, and train faster and more reliably. Below is the new DDQN equation for updating the target value.

# %% [markdown]
# $$ Q \text{-}target = r + γQ(s',\arg \max(Q(s’,a,\theta),\theta')) $$

# %%
tf.reset_default_graph()
mainQN = Qnetwork(h_size)
targetQN = Qnetwork(h_size)

init = tf.global_variables_initializer()

saver = tf.train.Saver()

trainables = tf.trainable_variables()

targetOps = updateTargetGraph(trainables,tau)

myBuffer = experience_buffer()

#Set the rate of random action decrease. 
e = startE
stepDrop = (startE - endE)/annealing_steps

#create lists to contain total rewards and steps per episode
jList = []
rList = []
total_steps = 0

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path)

with tf.Session() as sess:
    sess.run(init)
    if load_model == True:
        print('Loading Model...')
        ckpt = tf.train.get_checkpoint_state(path)
        saver.restore(sess,ckpt.model_checkpoint_path)
    for i in range(num_episodes):
        episodeBuffer = experience_buffer()
        #Reset environment and get first new observation
        s = env.reset()
        s = processState(s)
        d = False
        rAll = 0
        j = 0
        #The Q-Network
        while j < max_epLength: #If the agent takes longer than 50 moves to reach either of the blocks, end the trial.
            j+=1
            #Choose an action by greedily (with e chance of random action) from the Q-network
            if np.random.rand(1) < e or total_steps < pre_train_steps:
                a = np.random.randint(0,4)
            else:
                a = sess.run(mainQN.predict,feed_dict={mainQN.scalarInput:[s]})[0]
            total_steps += 1
            
            ################################################################################
            # TODO: Save the experience to our episode buffer.                             #
            # You will need to do the following:                                           #
            # (1) Get new state s1 (resized), reward r and done d from a                   #
            # (2) Add experience to episode buffer. Hint: experience includes              #
            #     s, a, r, s1 and d.                                                       #
            ################################################################################
            s1, r, d = env.step(a) # s1 is 84,84,3
            s1 = processState(s1)
            myBuffer.add([(s,a,r,s1,d)])
            ################################################################################
            #                                 END OF YOUR CODE                             #
            ################################################################################
            
            if total_steps > pre_train_steps:
                if e > endE:
                    e -= stepDrop
                
                if total_steps % (update_freq) == 0:
                    
                    ################################################################################
                    # TODO: Implement Double-DQN                                                   #
                    # (1) Get a random batch of experiences via experience_buffer class            #
                    #                                                                              #
                    # (2) Perform the Double-DQN update to the target Q-values                     #
                    #     Hint: Use mainQN and targetQN separately to chose an action and predict  #
                    #     the Q-values for that action.                                            #
                    #     Then compute targetQ based on Double-DQN equation                        #
                    #                                                                              #
                    # (3) Update the primary network with our target values                        #
                    ################################################################################ 
                    # get the replay data and transform into proper shape
                    train_np = myBuffer.sample(batch_size)
                    s_train = np.stack(train_np[:,0])
                    a_train = np.array(train_np[:,1])
                    r_train = np.array(train_np[:,2])
                    s1_train = np.stack(train_np[:,3])
                    d_train = np.array(train_np[:,4])
                    
                    # get the action by using mainQN in the s1 
                    a_s1 = sess.run(mainQN.predict,feed_dict={mainQN.scalarInput:s1_train})
                    # get the Q-values in state s1
                    q_s1 = sess.run(targetQN.Qout, feed_dict={targetQN.scalarInput:s1_train})
                    
                    target = r_train + (1 - d_train) * y * q_s1[np.arange(batch_size),a_s1]
                    sess.run( mainQN.updateModel, feed_dict={mainQN.scalarInput: s_train, mainQN.targetQ: target, mainQN.actions: a_train})
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
                           
                    updateTarget(targetOps,sess) #Update the target network toward the primary network.
            rAll += r
            s = s1
            
            if d == True:

                break
        
        myBuffer.add(episodeBuffer.buffer)
        jList.append(j)
        rList.append(rAll)
        #Periodically save the model. 
        if i % 2000 == 0:     # i % 1000 == 0:
            saver.save(sess,path+'/model-'+str(i)+'.ckpt')
            print("Saved Model")
        if len(rList) % 10 == 0:
            print("Episode",i,"reward:",np.mean(rList[-10:]))
    saver.save(sess,path+'/model-'+str(i)+'.ckpt')
print("Mean reward per episode: " + str(sum(rList)/num_episodes))
# Out:
# WARNING:tensorflow:From <ipython-input-6-78c45a01932e>:39: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Saved Model
# Episode 9 reward: 3.7
# Episode 19 reward: 1.2
# Episode 29 reward: 2.0
# Episode 39 reward: 1.7
# Episode 49 reward: 3.6
# Episode 59 reward: 1.1
# Episode 69 reward: 2.9
# Episode 79 reward: 1.7
# Episode 89 reward: 1.9
# Episode 99 reward: 0.6
# Episode 109 reward: 2.1
# Episode 119 reward: 3.1
# Episode 129 reward: 2.4
# Episode 139 reward: 2.1
# Episode 149 reward: 1.8
# Episode 159 reward: 0.7
# Episode 169 reward: 1.0
# Episode 179 reward: 1.4
# Episode 189 reward: 1.6
# Episode 199 reward: 1.9
# Episode 209 reward: 2.6
# Episode 219 reward: 2.1
# Episode 229 reward: 3.5
# Episode 239 reward: 1.0
# Episode 249 reward: 1.5
# Episode 259 reward: 2.9
# Episode 269 reward: 1.9
# Episode 279 reward: 2.0
# Episode 289 reward: 2.1
# Episode 299 reward: 1.5
# Episode 309 reward: 2.4
# Episode 319 reward: 1.4
# Episode 329 reward: 3.6
# Episode 339 reward: 2.5
# Episode 349 reward: 2.8
# Episode 359 reward: 2.0
# Episode 369 reward: 2.5
# Episode 379 reward: 3.5
# Episode 389 reward: 3.2
# Episode 399 reward: 2.5
# Episode 409 reward: 3.6
# Episode 419 reward: 2.5
# Episode 429 reward: 2.4
# Episode 439 reward: 2.2
# Episode 449 reward: 3.3
# Episode 459 reward: 4.5
# Episode 469 reward: 3.8
# Episode 479 reward: 5.4
# Episode 489 reward: 3.9
# Episode 499 reward: 6.7
# Episode 509 reward: 6.9
# Episode 519 reward: 4.9
# Episode 529 reward: 7.8
# Episode 539 reward: 7.7
# Episode 549 reward: 8.8
# Episode 559 reward: 14.5
# Episode 569 reward: 6.6
# Episode 579 reward: 9.4
# Episode 589 reward: 10.9
# Episode 599 reward: 11.0
# Episode 609 reward: 14.0
# Episode 619 reward: 14.2
# Episode 629 reward: 14.6
# Episode 639 reward: 10.7
# Episode 649 reward: 14.3
# Episode 659 reward: 13.2
# Episode 669 reward: 13.8
# Episode 679 reward: 14.2
# Episode 689 reward: 14.2
# Episode 699 reward: 16.6
# Episode 709 reward: 15.2
# Episode 719 reward: 16.1
# Episode 729 reward: 18.8
# Episode 739 reward: 19.4
# Episode 749 reward: 19.4
# Episode 759 reward: 19.7
# Episode 769 reward: 17.6
# Episode 779 reward: 16.6
# Episode 789 reward: 22.4
# Episode 799 reward: 15.9
# Episode 809 reward: 20.0
# Episode 819 reward: 18.4
# Episode 829 reward: 24.1
# Episode 839 reward: 18.1
# Episode 849 reward: 20.4
# Episode 859 reward: 19.9
# Episode 869 reward: 18.9
# Episode 879 reward: 17.2
# Episode 889 reward: 19.3
# Episode 899 reward: 18.0
# Episode 909 reward: 22.0
# Episode 919 reward: 20.3
# Episode 929 reward: 22.8
# Episode 939 reward: 19.8
# Episode 949 reward: 19.5
# Episode 959 reward: 19.7
# Episode 969 reward: 19.1
# Episode 979 reward: 21.9
# Episode 989 reward: 18.1
# Episode 999 reward: 20.2
# Episode 1009 reward: 21.7
# Episode 1019 reward: 16.6
# Episode 1029 reward: 19.7
# Episode 1039 reward: 21.3
# Episode 1049 reward: 20.3
# Episode 1059 reward: 23.9
# Episode 1069 reward: 18.3
# Episode 1079 reward: 20.0
# Episode 1089 reward: 20.1
# Episode 1099 reward: 23.3
# Episode 1109 reward: 21.1
# Episode 1119 reward: 21.6
# Episode 1129 reward: 17.6
# Episode 1139 reward: 21.1
# Episode 1149 reward: 21.7
# Episode 1159 reward: 17.7
# Episode 1169 reward: 21.1
# Episode 1179 reward: 22.7
# Episode 1189 reward: 21.4
# Episode 1199 reward: 18.5
# Episode 1209 reward: 19.5
# Episode 1219 reward: 21.0
# Episode 1229 reward: 20.6
# Episode 1239 reward: 22.4
# Episode 1249 reward: 22.1
# Episode 1259 reward: 22.3
# Episode 1269 reward: 22.5
# Episode 1279 reward: 18.2
# Episode 1289 reward: 21.6
# Episode 1299 reward: 20.3
# Episode 1309 reward: 21.6
# Episode 1319 reward: 24.8
# Episode 1329 reward: 24.0
# Episode 1339 reward: 19.9
# Episode 1349 reward: 22.2
# Episode 1359 reward: 22.5
# Episode 1369 reward: 19.2
# Episode 1379 reward: 19.7
# Episode 1389 reward: 20.1
# Episode 1399 reward: 20.1
# Episode 1409 reward: 19.4
# Episode 1419 reward: 21.8
# Episode 1429 reward: 20.7
# Episode 1439 reward: 22.3
# Episode 1449 reward: 20.3
# Episode 1459 reward: 22.2
# Episode 1469 reward: 23.3
# Episode 1479 reward: 19.8
# Episode 1489 reward: 20.0
# Episode 1499 reward: 23.8
# Episode 1509 reward: 22.9
# Episode 1519 reward: 21.0
# Episode 1529 reward: 22.9
# Episode 1539 reward: 21.2
# Episode 1549 reward: 22.8
# Episode 1559 reward: 21.6
# Episode 1569 reward: 23.9
# Episode 1579 reward: 20.4
# Episode 1589 reward: 20.1
# Episode 1599 reward: 22.3
# Episode 1609 reward: 21.4
# Episode 1619 reward: 21.7
# Episode 1629 reward: 19.4
# Episode 1639 reward: 21.7
# Episode 1649 reward: 22.2
# Episode 1659 reward: 21.8
# Episode 1669 reward: 21.7
# Episode 1679 reward: 18.8
# Episode 1689 reward: 24.4
# Episode 1699 reward: 22.0
# Episode 1709 reward: 22.5
# Episode 1719 reward: 21.2
# Episode 1729 reward: 22.4
# Episode 1739 reward: 20.2
# Episode 1749 reward: 22.9
# Episode 1759 reward: 22.4
# Episode 1769 reward: 21.2
# Episode 1779 reward: 25.0
# Episode 1789 reward: 22.7
# Episode 1799 reward: 20.6
# Episode 1809 reward: 22.7
# Episode 1819 reward: 23.4
# Episode 1829 reward: 21.6
# Episode 1839 reward: 22.5
# Episode 1849 reward: 22.9
# Episode 1859 reward: 21.3
# Episode 1869 reward: 23.8
# Episode 1879 reward: 21.9
# Episode 1889 reward: 19.9
# Episode 1899 reward: 21.2
# Episode 1909 reward: 22.1
# Episode 1919 reward: 21.4
# Episode 1929 reward: 19.6
# Episode 1939 reward: 22.2
# Episode 1949 reward: 21.4
# Episode 1959 reward: 24.3
# Episode 1969 reward: 23.0
# Episode 1979 reward: 21.9
# Episode 1989 reward: 21.3
# Episode 1999 reward: 19.6
# Saved Model
# Episode 2009 reward: 21.1
# Episode 2019 reward: 21.2
# Episode 2029 reward: 22.0
# Episode 2039 reward: 22.1
# Episode 2049 reward: 22.0
# Episode 2059 reward: 22.6
# Episode 2069 reward: 22.5
# Episode 2079 reward: 23.0
# Episode 2089 reward: 23.1
# Episode 2099 reward: 23.6
# Episode 2109 reward: 23.4
# Episode 2119 reward: 23.0
# Episode 2129 reward: 21.8
# Episode 2139 reward: 19.4
# Episode 2149 reward: 24.5
# Episode 2159 reward: 20.5
# Episode 2169 reward: 22.9
# Episode 2179 reward: 22.5
# Episode 2189 reward: 23.2
# Episode 2199 reward: 21.7
# Episode 2209 reward: 20.9
# Episode 2219 reward: 22.5
# Episode 2229 reward: 23.9
# Episode 2239 reward: 21.1
# Episode 2249 reward: 20.4
# Episode 2259 reward: 20.3
# Episode 2269 reward: 20.9
# Episode 2279 reward: 21.5
# Episode 2289 reward: 20.3
# Episode 2299 reward: 21.9
# Episode 2309 reward: 21.9
# Episode 2319 reward: 21.6
# Episode 2329 reward: 23.2
# Episode 2339 reward: 23.1
# Episode 2349 reward: 22.2
# Episode 2359 reward: 22.4
# Episode 2369 reward: 21.7
# Episode 2379 reward: 22.5
# Episode 2389 reward: 23.6
# Episode 2399 reward: 22.0
# Episode 2409 reward: 23.8
# Episode 2419 reward: 21.5
# Episode 2429 reward: 22.3
# Episode 2439 reward: 20.5
# Episode 2449 reward: 19.7
# Episode 2459 reward: 21.0
# Episode 2469 reward: 21.9
# Episode 2479 reward: 24.0
# Episode 2489 reward: 22.4
# Episode 2499 reward: 23.2
# Episode 2509 reward: 23.3
# Episode 2519 reward: 21.6
# Episode 2529 reward: 23.6
# Episode 2539 reward: 22.5
# Episode 2549 reward: 21.5
# Episode 2559 reward: 22.7
# Episode 2569 reward: 22.8
# Episode 2579 reward: 19.9
# Episode 2589 reward: 22.0
# Episode 2599 reward: 23.4
# Episode 2609 reward: 20.5
# Episode 2619 reward: 24.0
# Episode 2629 reward: 22.0
# Episode 2639 reward: 21.3
# Episode 2649 reward: 21.7
# Episode 2659 reward: 22.0
# Episode 2669 reward: 21.4
# Episode 2679 reward: 21.7
# Episode 2689 reward: 24.1
# Episode 2699 reward: 17.9
# Episode 2709 reward: 25.0
# Episode 2719 reward: 21.2
# Episode 2729 reward: 23.9
# Episode 2739 reward: 23.9
# Episode 2749 reward: 23.5
# Episode 2759 reward: 21.6
# Episode 2769 reward: 21.6
# Episode 2779 reward: 22.0
# Episode 2789 reward: 22.3
# Episode 2799 reward: 23.9
# Episode 2809 reward: 20.0
# Episode 2819 reward: 19.8
# Episode 2829 reward: 22.9
# Episode 2839 reward: 20.3
# Episode 2849 reward: 24.2
# Episode 2859 reward: 23.4
# Episode 2869 reward: 19.6
# Episode 2879 reward: 23.2
# Episode 2889 reward: 25.3
# Episode 2899 reward: 20.7
# Episode 2909 reward: 21.3
# Episode 2919 reward: 23.5
# Episode 2929 reward: 23.0
# Episode 2939 reward: 21.2
# Episode 2949 reward: 22.1
# Episode 2959 reward: 22.2
# Episode 2969 reward: 23.0
# Episode 2979 reward: 20.7
# Episode 2989 reward: 22.8
# Episode 2999 reward: 21.2
# Episode 3009 reward: 21.5
# Episode 3019 reward: 23.1
# Episode 3029 reward: 23.0
# Episode 3039 reward: 22.3
# Episode 3049 reward: 23.7
# Episode 3059 reward: 22.1
# Episode 3069 reward: 24.2
# Episode 3079 reward: 22.2
# Episode 3089 reward: 23.0
# Episode 3099 reward: 20.6
# Episode 3109 reward: 21.4
# Episode 3119 reward: 22.0
# Episode 3129 reward: 22.4
# Episode 3139 reward: 21.5
# Episode 3149 reward: 21.9
# Episode 3159 reward: 22.0
# Episode 3169 reward: 22.4
# Episode 3179 reward: 22.3
# Episode 3189 reward: 22.4
# Episode 3199 reward: 23.4
# Episode 3209 reward: 22.6
# Episode 3219 reward: 23.0
# Episode 3229 reward: 22.0
# Episode 3239 reward: 19.4
# Episode 3249 reward: 23.7
# Episode 3259 reward: 24.7
# Episode 3269 reward: 22.3
# Episode 3279 reward: 20.8
# Episode 3289 reward: 21.8
# Episode 3299 reward: 23.8
# Episode 3309 reward: 22.0
# Episode 3319 reward: 21.8
# Episode 3329 reward: 22.9
# Episode 3339 reward: 22.6
# Episode 3349 reward: 22.1
# Episode 3359 reward: 25.2
# Episode 3369 reward: 23.2
# Episode 3379 reward: 23.8
# Episode 3389 reward: 19.8
# Episode 3399 reward: 23.4
# Episode 3409 reward: 22.2
# Episode 3419 reward: 23.5
# Episode 3429 reward: 21.8
# Episode 3439 reward: 22.6
# Episode 3449 reward: 24.2
# Episode 3459 reward: 23.0
# Episode 3469 reward: 23.6
# Episode 3479 reward: 20.1
# Episode 3489 reward: 22.3
# Episode 3499 reward: 18.4
# Episode 3509 reward: 23.7
# Episode 3519 reward: 20.6
# Episode 3529 reward: 23.7
# Episode 3539 reward: 23.3
# Episode 3549 reward: 22.7
# Episode 3559 reward: 24.9
# Episode 3569 reward: 23.8
# Episode 3579 reward: 22.9
# Episode 3589 reward: 21.1
# Episode 3599 reward: 21.6
# Episode 3609 reward: 22.2
# Episode 3619 reward: 22.9
# Episode 3629 reward: 20.6
# Episode 3639 reward: 22.0
# Episode 3649 reward: 19.0
# Episode 3659 reward: 24.3
# Episode 3669 reward: 23.0
# Episode 3679 reward: 21.8
# Episode 3689 reward: 22.2
# Episode 3699 reward: 22.7
# Episode 3709 reward: 23.7
# Episode 3719 reward: 22.4
# Episode 3729 reward: 22.3
# Episode 3739 reward: 24.5
# Episode 3749 reward: 22.4
# Episode 3759 reward: 24.4
# Episode 3769 reward: 22.1
# Episode 3779 reward: 18.9
# Episode 3789 reward: 20.7
# Episode 3799 reward: 23.3
# Episode 3809 reward: 18.5
# Episode 3819 reward: 23.0
# Episode 3829 reward: 22.4
# Episode 3839 reward: 22.1
# Episode 3849 reward: 20.0
# Episode 3859 reward: 20.8
# Episode 3869 reward: 22.3
# Episode 3879 reward: 22.3
# Episode 3889 reward: 24.6
# Episode 3899 reward: 23.8
# Episode 3909 reward: 21.8
# Episode 3919 reward: 21.6
# Episode 3929 reward: 23.4
# Episode 3939 reward: 22.6
# Episode 3949 reward: 24.3
# Episode 3959 reward: 26.0
# Episode 3969 reward: 24.5
# Episode 3979 reward: 23.3
# Episode 3989 reward: 23.0
# Episode 3999 reward: 20.4
# Saved Model
# Episode 4009 reward: 23.1
# Episode 4019 reward: 21.7
# Episode 4029 reward: 22.7
# Episode 4039 reward: 23.1
# Episode 4049 reward: 21.7
# Episode 4059 reward: 21.7
# Episode 4069 reward: 21.8
# Episode 4079 reward: 25.5
# Episode 4089 reward: 22.5
# Episode 4099 reward: 20.7
# Episode 4109 reward: 22.4
# Episode 4119 reward: 22.1
# Episode 4129 reward: 22.8
# Episode 4139 reward: 21.6
# Episode 4149 reward: 22.0
# Episode 4159 reward: 23.0
# Episode 4169 reward: 22.6
# Episode 4179 reward: 23.5
# Episode 4189 reward: 21.5
# Episode 4199 reward: 24.5
# Episode 4209 reward: 20.3
# Episode 4219 reward: 21.2
# Episode 4229 reward: 22.0
# Episode 4239 reward: 24.0
# Episode 4249 reward: 22.7
# Episode 4259 reward: 23.4
# Episode 4269 reward: 21.6
# Episode 4279 reward: 23.2
# Episode 4289 reward: 22.1
# Episode 4299 reward: 24.2
# Episode 4309 reward: 23.5
# Episode 4319 reward: 20.5
# Episode 4329 reward: 23.4
# Episode 4339 reward: 21.4
# Episode 4349 reward: 24.0
# Episode 4359 reward: 24.1
# Episode 4369 reward: 22.2
# Episode 4379 reward: 23.6
# Episode 4389 reward: 25.4
# Episode 4399 reward: 22.4
# Episode 4409 reward: 21.1
# Episode 4419 reward: 24.0
# Episode 4429 reward: 23.5
# Episode 4439 reward: 19.2
# Episode 4449 reward: 22.8
# Episode 4459 reward: 23.3
# Episode 4469 reward: 22.4
# Episode 4479 reward: 23.7
# Episode 4489 reward: 23.1
# Episode 4499 reward: 21.7
# Episode 4509 reward: 23.5
# Episode 4519 reward: 21.6
# Episode 4529 reward: 21.6
# Episode 4539 reward: 23.4
# Episode 4549 reward: 19.8
# Episode 4559 reward: 21.9
# Episode 4569 reward: 22.7
# Episode 4579 reward: 21.3
# Episode 4589 reward: 24.1
# Episode 4599 reward: 20.7
# Episode 4609 reward: 23.7
# Episode 4619 reward: 21.6
# Episode 4629 reward: 21.7
# Episode 4639 reward: 22.7
# Episode 4649 reward: 22.8
# Episode 4659 reward: 21.8
# Episode 4669 reward: 20.6
# Episode 4679 reward: 21.2
# Episode 4689 reward: 21.3
# Episode 4699 reward: 21.7
# Episode 4709 reward: 21.6
# Episode 4719 reward: 22.8
# Episode 4729 reward: 18.1
# Episode 4739 reward: 23.5
# Episode 4749 reward: 21.2
# Episode 4759 reward: 22.7
# Episode 4769 reward: 20.9
# Episode 4779 reward: 23.8
# Episode 4789 reward: 22.5
# Episode 4799 reward: 18.8
# Episode 4809 reward: 21.4
# Episode 4819 reward: 24.3
# Episode 4829 reward: 20.8
# Episode 4839 reward: 22.3
# Episode 4849 reward: 20.5
# Episode 4859 reward: 23.8
# Episode 4869 reward: 21.4
# Episode 4879 reward: 25.0
# Episode 4889 reward: 25.0
# Episode 4899 reward: 23.1
# Episode 4909 reward: 21.3
# Episode 4919 reward: 20.3
# Episode 4929 reward: 22.2
# Episode 4939 reward: 23.9
# Episode 4949 reward: 22.6
# Episode 4959 reward: 24.1
# Episode 4969 reward: 22.3
# Episode 4979 reward: 22.3
# Episode 4989 reward: 22.9
# Episode 4999 reward: 22.7
# Mean reward per episode: 19.5376

# %% [markdown]
# It takes about 40 minutes to train 5000 episodes in Lab 4 machines. Mean reward per episode (50 steps) should be around 20

# %% [markdown]
# ### Checking network learning

# %% [markdown]
# Mean reward over time

# %%
rMat = np.resize(np.array(rList),[len(rList)//100,100])
rMean = np.average(rMat,1)
plt.plot(rMean)

# %% [markdown]
# ## Inline Question:
# Try a basic DQN without Dueling DQN and Double DQN (i.e. only one single network, no decomposition of the Q-function). You don't need to provide detailed source, just some quantitative comparison is OK (e.g. by comparing the mean reward). **
#
# **Your answer:** *Fill this in*
